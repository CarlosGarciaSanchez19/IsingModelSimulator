# %%
from IsingModel import IsingModelClass

# %% [markdown]
# Experiment 1:
#
# $T < T_c$
#
# $T = 25\space^\circ C$
#
# $J = 3\cdot 10^{-21}\space J$
#
# $h = 0\space J$

# %%
steps = 1000000
size = 250
j = 3e-21
h = 0
temperature = 298 # 25 Celsius
model = IsingModelClass(size, temperature)
model.J = j
model.h = h
print(model)

model.animate(steps, "ising_model_1")
model.plot_magnetization(steps)
model.plot_energy(steps)
# Out:
# 2D Ising Model with 250x250 spins
# T = 298.00 K
# J = 3e-21 Jules
# h = 0 Jules
# Curie temperature: 493.07 K

# %% [markdown]
# Experiment 2:
#
# $T = T_c$
#
# $T = 220\space^\circ C$
#
# $J = 3\cdot 10^{-21}\space J$
#
# $h = 0\space J$

# %%
steps = 1000000
size = 250
j = 3e-21
h = 0
temperature = 493.0694412100675 # 220.07 Celsius
model = IsingModelClass(size, temperature)
model.J = j
model.h = h
print(model)

model.animate(steps, "ising_model_Curie")
model.plot_magnetization(steps)
model.plot_energy(steps)
# Out:
# 2D Ising Model with 250x250 spins
# T = 493.07 K
# J = 3e-21 Jules
# h = 0 Jules
# Curie temperature: 493.07 K

# %% [markdown]
# Experiment 3:
#
# $T > T_c$
#
# $T = 327\space^\circ C$
#
# $J = 3\cdot 10^{-21}\space J$
#
# $h = 0\space J$

# %%
steps = 1000000
size = 250
j = 3e-21
h = 0
temperature = 600 # 327 Celsius
model = IsingModelClass(size, temperature)
model.J = j
model.h = h
print(model)

model.animate(steps, "ising_model_2")
model.plot_magnetization(steps)
model.plot_energy(steps)
# Out:
# 2D Ising Model with 250x250 spins
# T = 600.00 K
# J = 3e-21 Jules
# h = 0 Jules
# Curie temperature: 493.07 K

# %% [markdown]
# Experiment 4:
#
# $T > T_c$
#
# $T = 327\space^\circ C$
#
# $J = 3\cdot 10^{-21}\space J$
#
# $h = 10^{-21}\space J$

# %%
steps = 1000000
size = 250
j = 3e-21
h = 3e-21
temperature = 600 # 327 Celsius
model = IsingModelClass(size, temperature)
model.J = j
model.h = h
print(model)

model.animate(steps, "ising_model_3")
model.plot_magnetization(steps)
model.plot_energy(steps)
# Out:
# 2D Ising Model with 250x250 spins
# T = 600.00 K
# J = 3e-21 Jules
# h = 3e-21 Jules
# Curie temperature: 493.07 K
